# %%
import gzip, json, csv, os
import pandas as pd
import ast
from datetime import timedelta, date
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
rcParams['figure.figsize'] = (20, 6)

# %%
infilepath = '/vagrant/data/authorStat_small.txt.gz'
table = pd.read_csv(gzip.open(infilepath , 'r'))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-2-1d83670d6408> in <module>()
#       1 infilepath = '/vagrant/data/authorStat_small.txt.gz'
# ----> 2 table = pd.read_csv(gzip.open(infilepath , 'r'))
#
# ...

# %%
table.saef = table.saef.str.replace('None','')
table.laef = table.laef.str.replace('None','')
table.faef = table.faef.str.replace('None','')
table.maef = table.maef.str.replace('None','')
table.flay = table.flay.str.replace('None','')
table.ffay = table.ffay.str.replace('None','')
table.laay = table.laay.str.replace('None','')

# %%
table = table.convert_objects(convert_numeric=True)

# %%
infilepath = '/vagrant/cs109_firstOrPerish/analysis/filteredAuthors.csv.gz'
authors = pd.read_csv( gzip.open(infilepath, 'r'), usecols=[1])
# authors

# %%
authors = list(authors.author)

# %%
table2 = table[table.author.isin(authors)]

# %%
len(table2.author)

# %%
table2 = table2[table2.ffay > 1983]

# %%
# table2 = table2[table2.scl >= table2.fcl] # filter out cases where scientist career length is shorter than 
table2 = table2[table2.scl >= 3]

# %%
table2.dtypes
# Out:
# author     object
# scl       float64
# saef      float64
# tlap        int64
# laef      float64
# ffay      float64
# maef      float64
# flay      float64
# frqta     float64
# tcl       float64
# taap        int64
# laay      float64
# tfap        int64
# frqfa     float64
# fcl       float64
# faef      float64
# dtype: object

# %%
len(table2.author)
# Out:
# 1540981

# %%
np.random.seed(12345)
sample = np.random.choice(range(len(table2.author)), size=1000)
minisample = np.random.choice(range(len(table2.author)), size=100)

# %%
len(sample)
# Out:
# 1000

# %%
d = table2

# %%
d['rtd'] = (d.laay + 1.0/d.frqta) < 2014.0

# %%
# compare the distribution
d['la'] = d.tlap > 0
# d['adjfrqfa'] = d.frqfa * d.faef

# %%
d['nla'] = d.tlap == 0
d['nvrla'] = d.rtd & d.nla

# %%
k = d.frqfa * d.faef 
d['adjfrqfa']= k

# %%
d['logfrqfa'] = np.log10(d.frqfa)

# %%
d['logfrqta'] = np.log10(d.frqta)

# %%
d['logfaef'] = np.log10(d.faef)

# %%
d['logsaef'] = np.log10(d.saef)

# %%
d['logtaap'] = np.log10(d.taap)

# %%
# total scientist author paper
d['tsap'] = d.taap-d.tlap
d['logtsap'] = np.log10(d.tsap)

# %%
d['frqsa'] = d.tsap/d.scl
d['logfrqsa'] = np.log10(d.frqsa)

# %%
d = d[d.rtd == True]

# %%
np.median(d[d.la == True].adjfrqfa)
# Out:
# 0.10378274999996251

# %%
np.std(d[d.la == True].adjfrqfa)
# Out:
# 0.27936352993568736

# %%
np.median(d[d.la == False].adjfrqfa)
# Out:
# 0.0819545

# %%
# total frequency of science authorship doesn't matter!?
ax = d.boxplot(column='logfrqsa', by='la')

# %%
# It kind of seems like first authorship frequency matters, but hard to tell.
ax = d.boxplot(column='logfrqfa', by='la')

# %%
# First author quality doesn't matter
ax = d.boxplot(column='logfaef', by='la')

# %%
# total quality doesn't matter either
ax = d.boxplot(column='logsaef', by='la')

# %%
# ax = d.boxplot(column='frqfa', by='la')#

# %%
# total frequency seems to matter, but then again, last author paper is included here
ax = d.boxplot(column='logfrqta', by='la')

# %%
# this just shows that faculty has longer career
ax = d.boxplot(column='logtaap', by='la')

# %%
# this just shows that people who don't get faculty position just gives up earlier
ax = d.boxplot(column='logtsap', by='la')

# %%
# http://nbviewer.ipython.org/github/cs109/content/blob/master/labs/lab4/Lab4full.ipynb
from sklearn.linear_model import LogisticRegression
reg=1.
clf4 = LogisticRegression(C=reg)
clf4.fit(d.logfrqfa.reshape(-1,1), d.la)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
tempsnew=np.linspace(-5., 5., 100)
probs = clf4.predict_proba(tempsnew.reshape(-1,1))[:, 1]
predicts = clf4.predict(tempsnew.reshape(-1,1))

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#http://stanford.edu/~mwaskom/software/seaborn/tutorial/plotting_distributions.html
data1 = stats.poisson(2).rvs(100)
data2 = stats.poisson(5).rvs(120)
max_data = np.r_[data1, data2].max()
bins = np.linspace(0, max_data, max_data + 1)
plt.hist(data1, bins, normed=True, color="#6495ED", alpha=.5)
plt.hist(data2, bins, normed=True, color="#F08080", alpha=.5);

# %%
plt.scatter(d.logfrqfa[minisample], d.la[minisample])
axes=plt.gca()
axes.grid(False)
# remove_border(axes)
plt.plot(tempsnew, probs, marker='s')
plt.scatter(tempsnew, predicts, marker='s', color="green")

# %%
# select last authors
lastauthors = d[d.tlap > 0]

# %%
plt.figure()
plt.scatter(table2.frqfa[sample],table2.tlap[sample])

# %%
# plt.scatter(d.faef[sample], d.faef[sample])

# %%
plt.scatter(lastauthors.frqfa[sample],lastauthors.scl[sample])

# %%
plt.scatter(lastauthors.faef[sample],lastauthors.laef[sample])

# %%
plt.scatter(lastauthors.faef[sample], lastauthors.frqfa[sample])

# %%
plt.scatter(lastauthors.frqfa[sample], lastauthors.fcl[sample])

# %%
# d.boxplot(column='frqfa', by='la')#

# %%
# d.boxplot(column='faef', by='la')##

# %%
# d.boxplot(column='faef', by='scl')

# %%
# d.boxplot(column='scl', by='la')#

# %%
# d.boxplot(column='scl', by='laay')

# %%
# d.boxplot(column='tlap', by='scl')

# %%
# d.boxplot(column='tlap', by='laay')# not meaningful
